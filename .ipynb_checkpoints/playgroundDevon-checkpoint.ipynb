# %%
# 
import pandas as pd

df = pd.read_csv('NBA_Shot_dist - Sheet2.csv')

# %% [markdown]
# # Change column names

# %%
df.columns = ['name', 'team', 'szn', 'type', 'games', '0to8_makePrecent', '8to16_makePrecent', '16to24_makePrecent', '24plus_makePrecent', 'bcMake', '0to8_att', '8to16_att', '16to24_att', '24plus_att', 'bc_att', 'avgDist', 'avgMakeDist', 'avgMissDist']

# %% [markdown]
# # Delete irrelevant columns

# %%
del df['type']
del df['szn']
del df['bcMake']

# %%
df = df.sort_values('name')

# %% [markdown]
# # Bring in Salary Data
#
# *  Delete all columns except name and salary
# *  Rename two columns 'name' and 'salary'

# %%
salary_df = pd.read_csv('playerSalaries.csv')

# %%
del salary_df['Unnamed: 0']
del salary_df['2018/19']
del salary_df['2019/20']
del salary_df['2020/21']
del salary_df['2021/22']

salary_df.columns = ['name', 'salary']

# %% [markdown]
# # Sort Salary Data

# %%
salary_df = salary_df.sort_values('name')

# %% [markdown]
# # Merge Data sets
# ##### How? ...... inner

# %%
df = pd.merge(df, salary_df, how='inner')

# %% [markdown]
# # Get X,y
#
# * get rid of specail characters '$', and ','

# %%
import numpy as np

for col in df.select_dtypes([np.object]):
    df[col] = df[col].str.lstrip('$')
    


df = df.replace(regex={'$':'', ',':''})

df = df.loc[df['games'] >= 26]

# %% [markdown]
# # add more data
# * def_stats
#     * defensive win share
# * gen_stats
#     * age
#     * minutes played avg
#     * points per game
#     *

# %%
def_ws = pd.read_csv('NBA_Shot_dist - def_stats.csv')

def_ws = def_ws.iloc[:, [0,19]]

def_ws.columns = ['name', 'def_ws']

#------------------

def_gen = pd.read_csv('NBA_Shot_dist - gen_stats.csv')
def_gen = def_gen.iloc[:, [0,2,6,7,14,15,16,19,20,21,22,23,24,28]]
def_gen.columns = ['name','age','min','pts','ftm','fta','ftp','reb','ast','tov','stl','blk','pf','pm']

# %% [markdown]
# # Merge with main DF

# %%
df = pd.merge(df, def_ws, how='inner')
df = pd.merge(df, def_gen, how='inner')

# %% [markdown]
# # Delete certain columns

# %%
del df['0to8_att']
del df['8to16_att']
del df['16to24_att']
del df['24plus_att']
del df['avgMissDist']
del df['avgDist']
del df['bc_att']

# %% [markdown]
# # Get X, y as dataframes
# * make salary your 'y'
# * remove salary out of the middle of the df
# * make 'x' data frame

# %%
y = df.iloc[:, 8]
del df['salary']
X = df.iloc[:, 2:23]

# %% [markdown]
# # Turn Y into an intger

# %%
y = y.astype('int')

# %% [markdown]
# # Normalization

# %%
X
# Out:
#      games  0to8_makePrecent  8to16_makePrecent  16to24_makePrecent  \
# 0       29             0.400              0.600               0.600
# 1       47             0.620              0.363               0.289
# 2       34             0.395              0.200               0.000
# 3       61             0.609              0.428               0.475
# 4       31             0.607              0.586               0.313
# 5       55             0.490              0.238               0.107
# 6       59             0.510              0.370               0.382
# 7       64             0.477              0.545               0.154
# ..    ...  ...  ...  ...  ...  ...  ...
# 314   1.9  0.9  0.4  0.5  0.0  1.7 -1.5
# 315   4.4  1.6  0.8  1.5  0.2  2.0  5.5
# 316   4.7  1.2  0.9  0.4  0.3  1.8 -0.3
# 317   4.8  1.2  0.8  0.4  0.5  1.5  0.1
# 318   6.6  0.6  0.7  0.3  0.3  1.9 -2.6
# 319   1.6  0.6  0.7  0.3  0.1  1.7 -5.2
# 320   3.3  0.7  0.4  0.2  0.1  1.6 -0.6
# 321   2.3  1.4  0.7  0.3  0.1  1.1 -2.7
# 322   1.8  1.9  0.7  0.6  0.2  1.4 -0.4
# 323   3.4  2.3  1.1  0.8  0.5  2.1  0.6
# 324   1.8  4.4  1.8  1.0  0.1  1.7 -4.5
# 325   4.6  0.7  0.7  0.2  0.5  1.9  0.4
# 326   5.1  5.2  2.3  1.1  0.3  1.8  0.5
# 327   9.1  1.2  1.3  0.3  0.6  2.3 -5.3
# 328   1.6  2.8  0.7  1.2  0.1  1.3  2.2
# 329   5.2  4.3  2.9  2.4  0.8  2.3  4.5
# 330   2.6  1.2  0.6  0.7  0.4  1.7 -1.2
# 331   2.8  1.0  0.7  0.7  0.1  1.2  1.6
# 332   1.6  1.9  1.5  0.5  0.1  1.7 -2.9
# 333   2.9  0.8  0.7  1.0  0.8  2.0 -0.8
# 334   3.1  2.7  1.3  1.2  0.3  2.2 -5.1
# 335   5.0  4.1  1.8  1.0  0.6  2.1  1.5
# 336   7.0  2.4  1.5  1.1  0.9  2.5 -4.4
# 337   2.9  0.2  0.5  0.2  0.5  1.3  0.4
# 338   3.8  0.7  0.7  0.4  0.3  1.3  0.0
# 339   5.4  2.1  1.2  0.6  0.5  2.1  0.8
# 340   3.0  2.5  1.0  0.8  0.1  1.9  0.0
# 341   3.3  0.8  0.9  0.3  0.5  2.0  0.2
# 342   6.7  2.2  2.0  0.7  0.2  2.0 -6.0
# 343   4.7  1.6  1.0  0.6  0.2  1.8  2.8
#
# [344 rows x 20 columns]

# %% [markdown]
# # Train/Test split 70/30

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)

# %% [markdown]
# # First Run w/ Random Forest Classifer

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn import metrics

""" RANDOM FOREST PREDICTION """
# X, y = make_classification(n_samples=100, n_features=5, n_informative=5, n_redundant=0, random_state=0, shuffle=False)
clf = RandomForestClassifier(n_estimators=120, max_depth=25, random_state=0)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print(metrics.accuracy_score(y_test, y_pred), " -- Accuracy with Random Forests\n")
print("-------------- Importances per column with RF")
print((clf.feature_importances_), "\n")
# Out:
# 0.0673076923076923  -- Accuracy with Random Forests
#
# -------------- Importances per column with RF
# [0.05044319 0.05491385 0.05317709 0.05122454 0.04890959 0.05335486
#  0.05022871 0.05690085 0.05282702 0.05029502 0.04224432 0.04342287
#  0.05187173 0.05433081 0.04956383 0.0459346  0.0431036  0.04327643
#  0.04836301 0.05561408]

# %% [markdown]
# # Predictions

# %%
#print(clf.predict([[]]))
