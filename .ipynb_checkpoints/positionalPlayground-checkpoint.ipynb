# %% [markdown]
# # Predict position of NBA players

# %%
import pandas as pd

shot_stats = pd.read_csv('./csvData/NBA_Shot_dist - Sheet2.csv')
guards = pd.read_csv('./csvData/NBA_Shot_dist - guard_list.csv')
forwards = pd.read_csv('./csvData/NBA_Shot_dist - forwards_list.csv')
centers = pd.read_csv('./csvData/NBA_Shot_dist - center_list.csv')
playerHeight = pd.read_csv('./csvData/playerHeight.csv')

playerHeight = playerHeight.iloc[:, [0, 7, 9]]

shot_stats.columns = ['name', 'team', 'szn', 'type', 'games', '0to8_makePrecent', '8to16_makePrecent',
              '16to24_makePrecent', '24plus_makePrecent', 'bcMake', '0to8_att', 
              '8to16_att', '16to24_att', '24plus_att', 'bc_att', 'avgDist', 
              'avgMakeDist', 'avgMissDist']

position_df = pd.concat([guards, forwards, centers])

position_df = position_df.groupby(['name'], as_index=False).sum()

# %%
# merge
df = pd.merge(playerHeight, shot_stats, how='inner')
df = pd.merge(df, position_df, how='inner')

# %% [markdown]
# # Delete columns out of DF

# %%
del df['team']
del df['szn']
del df['type']
del df['0to8_att']
del df['8to16_att']
del df['16to24_att']
del df['24plus_att']
del df['avgMissDist']
del df['avgDist']
del df['bc_att']
del df['bcMake']

df
# Out:
#                       name  heightMeters  weightKilograms  games  \
# 0             Alex Abrines          1.98             86.2     64
# 1               Quincy Acy          2.01            108.9     59
# 2             Steven Adams          2.13            115.7     64
# 3            Arron Afflalo          1.96             95.3     46
# 4             Cole Aldrich          2.11            113.4     16
# 5        LaMarcus Aldridge          2.11            117.9     62
# 6               Tony Allen          1.93             96.6     20
# 7          Al-Farouq Aminu          2.06             99.8     55
# 8          Justin Anderson          1.98            103.4     28
# 9            Kyle Anderson          2.06            104.3     61
# 10           Ryan Anderson          2.08            108.9     57
# 11   Giannis Antetokounmpo          2.11            100.7     64
# 12         Carmelo Anthony          2.03            108.9     66
# 13            Trevor Ariza          2.03             97.5     55
# 14          Darrell Arthur          2.06            106.6     18
# 15               Omer Asik          2.13            115.7     14
# 16           D.J. Augustin          1.83             83.0     62
# 17            Luke Babbitt          2.06            102.1     46
# 18               Ron Baker          1.93             99.8     29
# 19         Wade Baldwin IV          1.93             91.6      1
# 20              J.J. Barea          1.83             83.9     63
# 21         Harrison Barnes          2.03            102.1     66
# 22             Will Barton          1.98             79.4     68
# 23           Nicolas Batum          2.03             90.7     55
# 24          Jerryd Bayless          1.90             90.7     39
# 25             Aron Baynes          2.08            117.9     67
# 26           Kent Bazemore          1.96             91.2     65
# 27            Bradley Beal          1.96             93.9     69
# 28           Malik Beasley          1.96             88.9     57
# 29         Michael Beasley          2.08            106.6     62
# ..                     ...           ...              ...    ...
# 349            Noah Vonleh          2.06            111.1     45
# 350         Nikola Vucevic          2.13            117.9     46
# 351            Dwyane Wade          1.93             99.8     58
# 352           Dion Waiters          1.93             99.8     30
# 353           Kemba Walker          1.85             83.5     67
# 354              John Wall          1.93             95.3     37
# 355              TJ Warren          2.03            102.1     64
# 356          Briante Weber          1.88             74.8     14
# 357             David West          2.06            113.4     57
# 358      Russell Westbrook          1.90             90.7     68
# 359            Okaro White          2.03             92.5      6
# 360       Isaiah Whitehead          1.93             96.6     16
# 361       Hassan Whiteside          2.13            120.2     47
# 362         Andrew Wiggins          2.03             90.3     69
# 363       Derrick Williams          2.03            108.9      2
# 364           Lou Williams          1.85             79.4     66
# 365        Marvin Williams          2.06            107.5     65
# 366          Troy Williams          2.01             95.3     13
# 367        Justise Winslow          2.01            102.1     55
# 368            Jeff Withey          2.13            104.8      9
# 369         Brandan Wright          2.08             95.3     28
# 370           Delon Wright          1.96             86.2     55
# 371            James Young          1.98             97.5      5
# 372              Joe Young          1.88             81.6     49
# 373             Nick Young          2.01             95.3     64
# 374         Thaddeus Young          2.03            100.2     69
# 375            Cody Zeller          2.13            108.9     33
# 376           Tyler Zeller          2.13            114.8     55
# 377            Paul Zipser          2.03             95.3     50
# 378            Ivica Zubac          2.16            108.9     29
#
#      0to8_makePrecent  8to16_makePrecent  16to24_makePrecent  \
# 0               0.477              0.545               0.154
# 1               0.419              0.273               0.273
# 2               0.658              0.484               0.250
# 3               0.571              0.370               0.250
# 4               0.273              0.000               0.000
# 5               0.631              0.422               0.397
# 6               0.536              0.667               0.200
# 7               0.490              0.238               0.107
# 8               0.559              0.286               0.286
# 9               0.593              0.507               0.400
# 10              0.571              0.478               0.567
# 11              0.668              0.359               0.345
# 12              0.509              0.452               0.381
# 13              0.572              0.000               0.167
# 14              0.750              0.250               0.750
# 15              0.385              1.000               0.000
# 16              0.507              0.276               0.476
# 17              0.500              0.519               0.529
# 18              0.381              0.000               0.200
# 19              0.000              0.000               0.000
# 20              0.583              0.376               0.353
# 21              0.549              0.381               0.451
# 22              0.550              0.403               0.289
# 23              0.646              0.457               0.373
# 24              0.621              0.273               0.286
# 25              0.505              0.458               0.459
# 26              0.491              0.319               0.402
# 27              0.616              0.435               0.417
# 28              0.522              0.308               0.400
# 29              0.601              0.411               0.329
# ..                ...                ...                 ...
# 349             0.553              0.455               0.393
# 350             0.661              0.421               0.500
# 351             0.601              0.361               0.384
# 352             0.534              0.348               0.348
# 353             0.497              0.392               0.446
# 354             0.563              0.304               0.297
# 355             0.615              0.420               0.401
# 356             0.500              0.200               0.000
# 357             0.692              0.614               0.446
# 358             0.579              0.381               0.395
# 359             0.500              1.000               0.000
# 360             0.538              0.182               0.600
# 361             0.605              0.394               0.442
# 362             0.631              0.346               0.341
# 363             0.500              0.000               0.000
# 364             0.532              0.454               0.421
# 365             0.556              0.447               0.389
# 366             0.676              0.000               0.500
# 367             0.483              0.260               0.095
# 368             1.000              0.000               0.000
# 369             0.634              0.333               0.500
# 370             0.567              0.133               0.250
# 371             0.500              0.000               0.000
# 372             0.553              0.407               0.406
# 373             0.656              0.595               0.421
# 374             0.570              0.358               0.468
# 375             0.562              0.778               0.381
# 376             0.606              0.375               0.417
# 377             0.480              0.391               0.225
# 378             0.545              0.273               0.000
#
#      24plus_makePrecent  avgMakeDist  guard  forward  center
# 0                 0.383        18.67      1        0       0
# 1                 0.326        19.52      0        1       0
# 2                 0.000         1.92      0        0       1
# 3                 0.411        15.13      1        0       0
# 4                 0.000         2.33      0        0       1
# 5                 0.313         7.93      0        1       0
# 6                 0.364         3.77      1        1       0
# 7                 0.389        14.84      0        1       0
# 8                 0.365        11.12      1        1       0
# 9                 0.286         6.40      0        1       0
# 10                0.383        18.65      0        1       0
# 11                0.297         5.46      0        1       0
# 12                0.360        15.85      0        1       0
# 13                0.378        15.77      1        1       0
# 14                0.333        15.57      0        1       0
# 15                0.000         3.29      0        0       1
# 16                0.435        15.21      1        0       0
# 17                0.410        19.97      0        1       0
# 18                0.333        14.80      1        0       0
# 19                0.000         0.00      1        0       0
# 20                0.362        13.40      1        0       0
# 21                0.350        11.11      0        1       0
# 22                0.366        10.62      1        1       0
# 23                0.346        15.34      1        1       0
# 24                0.370        14.61      1        0       0
# 25                0.000         6.66      0        0       1
# 26                0.393        13.45      1        0       0
# 27                0.376        12.94      1        0       0
# 28                0.321        11.89      1        0       0
# 29                0.397         6.81      0        1       0
# ..                  ...          ...    ...      ...     ...
# 349               0.282         8.03      0        1       0
# 350               0.339        11.04      0        0       1
# 351               0.299         8.63      1        0       0
# 352               0.308        11.94      1        0       0
# 353               0.398        14.54      1        0       0
# 354               0.363        10.08      1        0       0
# 355               0.213         6.44      0        1       0
# 356               0.444        12.30      1        0       0
# 357               0.333         7.63      0        1       0
# 358               0.284         8.85      1        0       0
# 359               0.364        15.86      0        1       0
# 360               0.389         7.48      1        0       0
# 361               1.000         4.42      0        0       1
# 362               0.328        10.43      0        1       0
# 363               0.000         1.00      0        1       0
# 364               0.363        13.34      1        0       0
# 365               0.412        14.43      0        1       0
# 366               0.227         5.93      0        1       0
# 367               0.461         8.51      0        1       0
# 368               0.200         8.33      0        0       1
# 369               0.000         2.19      0        1       1
# 370               0.372         7.98      1        0       0
# 371               0.300        20.75      1        1       0
# 372               0.386        13.69      1        0       0
# 373               0.389        19.08      1        1       0
# 374               0.335         7.60      0        1       0
# 375               0.667         4.13      0        1       1
# 376               0.357         4.03      0        0       1
# 377               0.344        15.00      0        1       0
# 378               0.000         2.15      0        0       1
#
# [379 rows x 12 columns]

# %% [markdown]
# # Make X and y - Test and Train sets

# %%
from sklearn.model_selection import train_test_split

X = df.iloc[:, 1:9]
y = df.iloc[:, 9:12]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)

# %% [markdown]
# # Use random forest to predict on all three positions

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn import metrics

""" RANDOM FOREST PREDICTION """
# X, y = make_classification(n_samples=100, n_features=5, n_informative=5, n_redundant=0, random_state=0, shuffle=False)
clf = RandomForestClassifier(n_estimators=500, max_depth=15, random_state=0)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print(metrics.accuracy_score(y_test, y_pred), " -- Accuracy with Random Forests\n")
print("-------------- Importances per column with RF")
print((clf.feature_importances_), "\n")
# Out:
# 0.7807017543859649  -- Accuracy with Random Forests
#
# -------------- Importances per column with RF
# [0.33907842 0.23258631 0.05175946 0.07659516 0.05507762 0.05342277
#  0.07839931 0.11308095]

# %% [markdown]
# # Spliting Y's up
# * Y1 = Guards
# * Y2 = Forwards
# * Y3 = Centers

# %%
y1 = y.iloc[:, 0]
X_train, X_test, y1_train, y1_test = train_test_split(X, y1, test_size=.3)

y2 = y.iloc[:, 0]
X_train, X_test, y2_train, y2_test = train_test_split(X, y2, test_size=.3)

y3 = y.iloc[:, 0]
X_train, X_test, y3_train, y3_test = train_test_split(X, y3, test_size=.3)

# %%
""" RANDOM FOREST PREDICTION """
# X, y = make_classification(n_samples=100, n_features=5, n_informative=5, n_redundant=0, random_state=0, shuffle=False)
clf = RandomForestClassifier(n_estimators=120, max_depth=10, random_state=0)
clf.fit(X_train, y1_train)
y1_pred = clf.predict(X_test)

print(metrics.accuracy_score(y1_test, y1_pred), " -- Accuracy with Random Forests\n")
print("-------------- Importances per column with RF")
print((clf.feature_importances_), "\n")
# Out:
# 0.5263157894736842  -- Accuracy with Random Forests
#
# -------------- Importances per column with RF
# [0.09214798 0.11929815 0.14004645 0.14102394 0.12588591 0.11226826
#  0.11797568 0.15135362]

# %% [markdown]
# # Logistic Regression

# %%
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression, LinearRegression

clf = LogisticRegression()
clf.fit(X_train, y1_train)
y1_pred = clf.predict(X_test)
print(metrics.accuracy_score(y1_test, y1_pred), " -- Accuracy with Logistic Regression\n")
# Out:
# 0.5175438596491229  -- Accuracy with Logistic Regression

# %%
clf = LinearRegression(normalize=True) 
clf.fit(X_train, y1_train) 
y1_pred = clf.predict(X_test) 
#print(metrics.accuracy_score(y1_test, y1_pred), " -- Accuracy with Linear Regression\n")
y1_pred
# Out:
# array([0.58327181, 0.42774635, 0.4767974 , 0.46166132, 0.44179578,
#        0.4330091 , 0.41026727, 0.37142484, 0.39585697, 0.43278285,
#        0.47706117, 0.34570546, 0.53474078, 0.47594558, 0.58704364,
#        0.43663427, 0.44244297, 0.66108158, 0.3592697 , 0.56450118,
#        0.50907948, 0.39919972, 0.4324437 , 0.3882477 , 0.45520474,
#        0.40620797, 0.46974507, 0.49519025, 0.4710711 , 0.6537219 ,
#        0.45835447, 0.56700518, 0.50972485, 0.40786618, 0.56311062,
#        0.36975913, 0.4069803 , 0.45156016, 0.46676171, 0.52241756,
#        0.58923649, 0.38647976, 0.39977475, 0.47585468, 0.38918184,
#        0.36827513, 0.42878467, 0.38436146, 0.4382557 , 0.42994207,
#        0.45098945, 0.38736335, 0.47355935, 0.35501464, 0.36319476,
#        0.43817829, 0.59159524, 0.40686987, 0.40051401, 0.44980898,
#        0.66536215, 0.49888583, 0.39361504, 0.41440142, 0.36803742,
#        0.45190423, 0.45049555, 0.33620165, 0.59730702, 0.39935926,
#        0.50878116, 0.61500611, 0.38606477, 0.47317018, 0.32574271,
#        0.5915438 , 0.51354159, 0.38188932, 0.66501298, 0.41157317,
#        0.38093794, 0.45959965, 0.37183786, 0.81366925, 0.43092578,
#        0.57516349, 0.54420116, 0.39134313, 0.43342979, 0.53828765,
#        0.42072547, 0.39820986, 0.43797415, 0.38143522, 0.39390853,
#        0.62422751, 0.40602853, 0.37052779, 0.42703056, 0.3961327 ,
#        0.44512265, 0.42079116, 0.41783908, 0.44346049, 0.5269104 ,
#        0.46507482, 0.57125899, 0.56203884, 0.51893559, 0.42380275,
#        0.39032418, 0.42187888, 0.47603077, 0.39656576])
